# %% [markdown]
# #### 森羊双十一天猫数据分析报告

# %%
# %load prep.py
# %load prep.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'].insert(0, 'SimHei')
plt.rcParams['axes.unicode_minus'] = False

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
orders_df = pd.read_excel('res/order2021.xlsx', true_values=['是'], false_values=['否'])
orders_df
# Out:
#                   orderID       userID   goodsID  price  num  orderAmount  \
# 0      sys-2021-129388536  user-233240  PR000366    838    1          838
# 1      sys-2021-129388537  user-184666  PR000716    836    4         3344
# 2      sys-2021-129388538  user-283751  PR000323   1648    1         1648
# 3      sys-2021-129388539  user-279635  PR000652    651    1          651
# 4      sys-2021-129388540  user-124652  PR000774   1415    2         2830
# ...                   ...          ...       ...    ...  ...          ...
# 33496  sys-2021-129422913  user-235535  PR000164    593    4         2372
# 33497  sys-2021-129422914  user-139042  PR000096    661    1          661
# 33498  sys-2021-129422915  user-133379  PR000984    696    1          696
# 33499  sys-2021-129422916  user-156013  PR000753   1484    4         5936
# 33500  sys-2021-129422917  user-271551  PR000738   1014    1         1014
#
#        payment discount           orderTime  chargeback
# 0          838      NaN 2021-01-05 00:01:11       False
# 1         3344      NaN 2021-01-05 00:02:12        True
# 2         1648      NaN 2021-01-05 00:02:46        True
# 3          651      NaN 2021-01-05 00:03:37       False
# 4         2830      NaN 2021-01-05 00:04:44       False
# ...        ...      ...                 ...         ...
# 33496     2372          2021-01-13 23:57:24        True
# 33497      661          2021-01-13 23:57:51       False
# 33498      696          2021-01-13 23:58:19       False
# 33499     5936          2021-01-13 23:59:24       False
# 33500     1014          2021-01-13 23:59:45       False
#
# [33501 rows x 10 columns]

# %%
orders_df['discount'] = orders_df.discount.replace(r'\s', '', regex=True).fillna('')

# %%
orders_df.shape
# Out:
# (33501, 10)

# %%
orders_df.discount.unique()
# Out:
# array(['', '3件8折', '2件9折', '1件95折', '满2700返180券', '满1800减80', '满600减30',
#        '满4400返320券', '满3600返180券', '4件以上7折', '满3000返210券', '满1200返50券',
#        '满2400减150', '满900返40券', '满600返30券', '满6000返660券', '满900减40',
#        '满4800减540', '满2600减120', '满200减10', '满2000减100', '满1100减40',
#        '满3600返240券', '满2800减140', '满800减30', '满1500返60券', '满1000返40券',
#        '满800返30券', '满5400减600', '满1600减80', '满4000减320', '满7200减780',
#        '满5100返330券', '满1500减90', '满1000减40', '满1800返70券', '满5200减400',
#        '满500减20', '满700返30券', '满3300减210', '满10000减900', '满1400返60券',
#        '满2800返140券', '满1600返80券', '满1600减60', '满2600返120券', '满3600返280券',
#        '满1200减50', '满7500返650券', '满3000减210', '满2000返100券', '满1500返90券',
#        '满3600减240', '满2400返120券', '满2400返160券', '满700减30', '满4000返350券',
#        '满2000减200', '满2700减180', '满2400返150券', '满2400减200', '满2200返100券',
#        '满1300减50', '满1600返120券', '满1200减60', '满1400返50券', '满2400减120',
#        '满3600减180', '满5500减500', '满3900返270券', '满3400减160', '满6600减720',
#        '满1800减120', '满2200减100', '满2800返240券', '满2100减150', '满2800返200券',
#        '满1100返40券', '满3200返240券', '满8400返900券', '满4800减360', '满4800返360券',
#        '满2800减200', '满4500返300券', '满1200返60券', '满800减40', '满4500减400',
#        '满500返20券', '满3900减240', '满6400返480券', '满1800返120券', '满6000返390券',
#        '满4000返320券', '满5600减440', '满4800返540券', '满3500减350', '满4400减320',
#        '满8400返960券', '满1800返80券', '满1700减60', '满2200减80', '满1400减60',
#        '满2000减160', '满6500减550', '满400减20', '满7800减900', '满3000减140',
#        '满4400返360券', '满5000减450', '满1600返60券', '满6000减720', '满3300返210券',
#        '满400返20券', '满7800减840', '满2100减120', '满2000返70券', '满3000返140券',
#        '满8000减600', '满3600返420券', '满3000返180券', '满7200减560', '满1900减70',
#        '满3600减280', '满3000减250', '满5600返400券', '满10500返950券',
#        '满4500返400券', '满1500减60', '满4800减300', '满4600减220', '满3000减180',
#        '满7200返840券', '满5700返390券', '满2000返160券', '满3900返240券',
#        '满4000返200券', '满2100返150券', '满1300返50券', '满1400减50', '满5200返400券',
#        '满6000减660', '满5000返450券', '满4500减300', '满1800减70', '满3200减240',
#        '满1200返90券', '满7000减650', '满800返40券', '满9600返1080券', '满2100返120券',
#        '满3500返300券', '满6800减520', '满3600减420', '满5400返600券', '满5400减360',
#        '满3500返350券', '满1600减120', '满4000减200', '满4200返270券', '满3500减300',
#        '满4800返300券', '满2500返250券', '满7200减840', '满6400减480', '满4000减280',
#        '满3200返160券', '满6000减390', '满4200减270', '满5400返360券', '满1700返60券',
#        '满2500减250', '满2400减160', '满5700减390', '满4000减350', '满7600返600券',
#        '满5500返500券', '满8000返600券', '满6600返720券', '满6000返550券',
#        '满7200返780券', '满1500减150', '满3600减360', '满7800返900券', '满3000减300',
#        '满6000返500券', '满3000返300券', '满9000减1020', '满2400返200券',
#        '满6900减450', '满6000返440券', '满6000减550', '满2000减70', '满4400减360',
#        '满3800减180', '满9500减850', '满3800返180券', '满2100返80券', '满5100减330',
#        '满7800返840券', '满300减20', '满1900返70券', '满4200返480券', '满5600返440券',
#        '满11400减1260', '满3200减160', '满7500减700', '满4000返280券', '满6600减780',
#        '满12000返1380券', '满9000返1020券', '满7000返600券', '满9000返800券',
#        '满6000减480', '满7200减520', '满4200返200券', '满10000返900券',
#        '满4800返330券', '满8500返750券', '满3000返250券', '满5700返360券',
#        '满3400返160券', '满7200返560券', '满4200返420券', '满6500返600券', '满600减20',
#        '满2000返200券', '满4000返400券', '满2800减240', '满8000返750券', '满6500减600',
#        '满6000返720券', '满4000减400', '满4200减420', '满2400减240', '满2500返200券',
#        '满3900减270', '满7000返650券', '满1800减240', '满4400减220', '满3600返360券',
#        '满7500返700券', '满1200减90', '满3000返360券', '满10200返1140券',
#        '满6000返480券', '满4800减330', '满4200减480', '满5400返660券', '满800减80',
#        '满7600返560券', '满10800返1200券', '满11000减1000', '满2300减80',
#        '满8000减700', '满2000返120券', '满2500减200', '满6300返420券', '满7600减560',
#        '满1200减80', '满12000减1320', '满6800返520券', '满9600减1020', '满7600减600',
#        '满10200减1140', '满6600减420', '满8000减750', '满5600减400', '满8400返640券',
#        '1件98折', '2件95折', '3件9折', '满1600减100', '满1400减80', '满1000减60',
#        '满3000减160', '满2000减120', '满1800减100', '满2600减140', '满3800减200',
#        '满2200减120', '满3400减180', '满2400减140', '满600减40', '满800减60',
#        '满3200减180', '满3600减200', '满6500返550券', '满4000减220', '满2600返90券',
#        '满4400减240', '满2800减160', '满12000返1320券', '满11200返840券',
#        '满4600减240', '满4800返480券', '满5200返260券', '满7800返510券',
#        '满9000返960券', '满7200返520券', '满5600返280券'], dtype=object)

# %%
# 对比预热期、活动期、返场期的GMV、净销售额、总订单数、成交订单数、总商品数、成交商品数、客单价、拒退率
def make_tag(day):
    if day < 8:
        return '预热期'
    elif day < 11:
        return '活动期'
    return '返场期'

# %%
orders_df['tag'] = orders_df.orderTime.dt.day.apply(make_tag).astype('category')
orders_df['tag'] = orders_df.tag.cat.reorder_categories(['预热期','活动期','返场期'])

# %%
temp_df1 = pd.pivot_table(
    orders_df,
    index = 'tag',
    values = ['orderAmount', 'orderID','num', 'userID'],
    aggfunc = {'orderAmount': 'sum',
               'orderID': 'nunique',
               'num': 'sum',
               'userID': 'nunique'}        
).reindex(
       columns = ['orderAmount', 'orderID', 'num', 'userID' ]
).rename(columns={'orderAmount': 'GMV',
                  'orderID':'总订单数',
                  'num': '总商品数',
                  'userID':'总用户数'})

temp_df1
# Out:
#           GMV   总订单数   总商品数   总用户数
# tag
# 预热期  18004237   6273  17155   6059
# 活动期  42794651  15441  40789  14769
# 返场期  31777545  11787  30331  11312

# %%
temp_df2 = pd.pivot_table(
    orders_df.query('not chargeback'),
    index = 'tag',
    values = ['payment', 'orderID','num', 'userID'],
    aggfunc = {'payment': 'sum',
               'orderID': 'nunique',
               'num': 'sum',
               'userID': 'nunique'}        
).reindex(
       columns = ['payment', 'orderID', 'num', 'userID' ]
).rename(columns={'payment': '净销售额',
                  'orderID':'成交订单数',
                  'num': '成交商品数',
                  'userID':'成交用户数'})

temp_df2
# Out:
#          净销售额  成交订单数  成交商品数  成交用户数
# tag
# 预热期  14841296   5164  14159   5006
# 活动期  25636091   9841  26050   9565
# 返场期  24215453   9392  24207   9079

# %%
result_df = pd.concat( (temp_df1, temp_df2), axis=1)
result_df
# Out:
#           GMV   总订单数   总商品数   总用户数      净销售额  成交订单数  成交商品数  成交用户数
# tag
# 预热期  18004237   6273  17155   6059  14841296   5164  14159   5006
# 活动期  42794651  15441  40789  14769  25636091   9841  26050   9565
# 返场期  31777545  11787  30331  11312  24215453   9392  24207   9079

# %%
result_df['客单价'] = np.round(result_df.净销售额 / result_df.总用户数, 2)
result_df['拒退率'] = 1-result_df.成交订单数 / result_df.总订单数
result_df
# Out:
#           GMV   总订单数   总商品数   总用户数      净销售额  成交订单数  成交商品数  成交用户数      客单价  \
# tag
# 预热期  18004237   6273  17155   6059  14841296   5164  14159   5006  2449.46
# 活动期  42794651  15441  40789  14769  25636091   9841  26050   9565  1735.80
# 返场期  31777545  11787  30331  11312  24215453   9392  24207   9079  2140.69
#
#           拒退率
# tag
# 预热期  0.176789
# 活动期  0.362671
# 返场期  0.203190

# %%
result_df.to_excel('question1.xlsx')

# %%
temp_df3 = pd.pivot_table(
    orders_df.query('not chargeback'),
    index = 'userID',
    values = ['orderID', 'payment','num'],
    aggfunc = {'orderID': 'nunique',
               'payment': 'sum',
               'num': 'sum',
                }        
).rename(columns={'num': '购买商品数',
                  'orderID':'订单数',
                  'payment': '消费金额'
                 }
)

temp_df3['是否购买'] = 1
temp_df3
# Out:
#              购买商品数  订单数  消费金额  是否购买
# userID
# user-100000      1    1  1195     1
# user-100032      4    2  5074     1
# user-100033      3    1  2154     1
# user-100034      1    1  1048     1
# user-100038      4    1  2616     1
# ...            ...  ...   ...   ...
# user-548272      1    1   978     1
# user-548274      7    1  9919     1
# user-548279      2    1  1848     1
# user-548280      4    1  4108     1
# user-548282      3    1  2685     1
#
# [23119 rows x 4 columns]

# %%
users_df = pd.read_excel('res/user2021.xlsx')
users_df
# Out:
#             userID user_name  age     phonenum sex       date chanelID
# 0      user-550507       WUe   39  182****7711   女 2021-01-12    渠道-52
# 1      user-499937        武久   30  177****7858   男 2021-01-08    渠道-89
# 2      user-515582       周亮l   39  188****6398   女 2021-01-09    渠道-89
# 3      user-519645       路洋h   34  167****6851   男 2021-01-10    渠道-00
# 4      user-487799       李宁g   26  148****1375   男 2021-01-03    渠道-52
# ...            ...       ...  ...          ...  ..        ...      ...
# 69390  user-531290        厉厉   24  193****8590   女 2021-01-08    渠道-52
# 69391  user-537409       出租尚   33  150****5113   女 2021-01-10    渠道-39
# 69392  user-511000       农qM   40  171****0753   女 2021-01-09    渠道-98
# 69393  user-518649       李玉兰   36  186****2539   女 2021-01-10    渠道-00
# 69394  user-545810        屈向   18  182****3850   女 2021-01-10    渠道-39
#
# [69395 rows x 7 columns]

# %%
users_df.drop(index=users_df[(users_df.date.dt.day < 5) |(users_df.date.dt.day > 13 )].index, inplace=True)
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66158 entries, 0 to 69394
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userID     66158 non-null  object
#  1   user_name  66149 non-null  object
#  2   age        66158 non-null  int64
#  3   phonenum   66158 non-null  object
#  4   sex        66158 non-null  object
#  5   date       66158 non-null  datetime64[ns]
#  6   chanelID   66158 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 4.0+ MB

# %%
users_df.drop(columns=['phonenum','user_name'],inplace=True)
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66158 entries, 0 to 69394
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   userID    66158 non-null  object
#  1   age       66158 non-null  int64
#  2   sex       66158 non-null  object
#  3   date      66158 non-null  datetime64[ns]
#  4   chanelID  66158 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 3.0+ MB

# %%
temp_df4 = pd.merge(temp_df3, users_df, how='right', on='userID').fillna(0)

# %%
#各个渠道在预热期、活动期、返场期拉新人数、转化率、营收贡献、客单价
(temp_df5 := pd.pivot_table(
    temp_df4,
    index='chanelID',
    values=['订单数','userID','是否购买', '购买商品数', '消费金额'],
    aggfunc={
        '订单数': 'sum',
        'userID': 'count',
        '是否购买': 'sum',
        '购买商品数': 'sum',
        '消费金额': 'sum'
    }
).applymap(int).rename(columns={'userID': '拉新用户数', '是否购买': '购买用户数'}))
# Out:
#           拉新用户数  购买用户数     消费金额   订单数  购买商品数
# chanelID
# 渠道-00      5360    466  1344906   491   1348
# 渠道-16      2826    232   601559   241    608
# 渠道-19      2168    186   554238   202    550
# 渠道-28      4090    389  1072763   410   1065
# 渠道-39      5663    501  1386851   530   1438
# 渠道-46      2805    248   643569   260    659
# 渠道-52      8434    767  2089450   814   2120
# 渠道-53      7909    731  1990945   764   1972
# 渠道-56      2841    274   822426   307    784
# 渠道-76      6213    594  1655802   633   1668
# 渠道-78      2246    206   547785   215    552
# 渠道-89     11331   1005  2806740  1059   2843
# 渠道-98      4272    396  1056999   420   1081

# %%
temp_df5['转化率'] = temp_df5['购买用户数'] / temp_df5['拉新用户数']
temp_df5['ARPU']=temp_df5['消费金额'] / temp_df5['拉新用户数']
temp_df5['ARPPU']=temp_df5['消费金额'] / temp_df5['购买用户数']
temp_df5
# Out:
#           拉新用户数  购买用户数     消费金额   订单数  购买商品数       转化率        ARPU  \
# chanelID
# 渠道-00      5360    466  1344906   491   1348  0.086940  250.915299
# 渠道-16      2826    232   601559   241    608  0.082095  212.865888
# 渠道-19      2168    186   554238   202    550  0.085793  255.644834
# 渠道-28      4090    389  1072763   410   1065  0.095110  262.289242
# 渠道-39      5663    501  1386851   530   1438  0.088469  244.896874
# 渠道-46      2805    248   643569   260    659  0.088414  229.436364
# 渠道-52      8434    767  2089450   814   2120  0.090941  247.741285
# 渠道-53      7909    731  1990945   764   1972  0.092426  251.731572
# 渠道-56      2841    274   822426   307    784  0.096445  289.484688
# 渠道-76      6213    594  1655802   633   1668  0.095606  266.506036
# 渠道-78      2246    206   547785   215    552  0.091719  243.893589
# 渠道-89     11331   1005  2806740  1059   2843  0.088695  247.704527
# 渠道-98      4272    396  1056999   420   1081  0.092697  247.424860
#
#                 ARPPU
# chanelID
# 渠道-00     2886.064378
# 渠道-16     2592.926724
# 渠道-19     2979.774194
# 渠道-28     2757.745501
# 渠道-39     2768.165669
# 渠道-46     2595.036290
# 渠道-52     2724.185137
# 渠道-53     2723.590971
# 渠道-56     3001.554745
# 渠道-76     2787.545455
# 渠道-78     2659.150485
# 渠道-89     2792.776119
# 渠道-98     2669.189394

# %%
temp_df4['tag'] = temp_df4.date.dt.day.apply(make_tag).astype('category')
temp_df4['tag']=temp_df4.tag.cat.reorder_categories(['预热期','活动期','返场期'])
temp_df4
# Out:
#             userID  购买商品数  订单数  消费金额  是否购买  age sex       date chanelID  tag
# 0      user-550507    0.0  0.0   0.0   0.0   39   女 2021-01-12    渠道-52  返场期
# 1      user-499937    0.0  0.0   0.0   0.0   30   男 2021-01-08    渠道-89  活动期
# 2      user-515582    0.0  0.0   0.0   0.0   39   女 2021-01-09    渠道-89  活动期
# 3      user-519645    0.0  0.0   0.0   0.0   34   男 2021-01-10    渠道-00  活动期
# 4      user-529356    0.0  0.0   0.0   0.0   24   女 2021-01-08    渠道-19  活动期
# ...            ...    ...  ...   ...   ...  ...  ..        ...      ...  ...
# 66153  user-531290    0.0  0.0   0.0   0.0   24   女 2021-01-08    渠道-52  活动期
# 66154  user-537409    0.0  0.0   0.0   0.0   33   女 2021-01-10    渠道-39  活动期
# 66155  user-511000    0.0  0.0   0.0   0.0   40   女 2021-01-09    渠道-98  活动期
# 66156  user-518649    0.0  0.0   0.0   0.0   36   女 2021-01-10    渠道-00  活动期
# 66157  user-545810    0.0  0.0   0.0   0.0   18   女 2021-01-10    渠道-39  活动期
#
# [66158 rows x 10 columns]

# %%
(temp_df6 := pd.pivot_table(
    temp_df4,
    index='chanelID',
    columns='tag',
    values=['订单数','userID','是否购买', '购买商品数', '消费金额'],
    aggfunc={
        '订单数': 'sum',
        'userID': 'count',
        '是否购买': 'sum',
        '购买商品数': 'sum',
        '消费金额': 'sum'
    }
).applymap(int).rename(columns={'userID': '拉新用户数', '是否购买': '购买用户数'}))
# Out:
#          拉新用户数             购买用户数            消费金额                订单数            \
# tag        预热期   活动期   返场期   预热期  活动期 返场期    预热期      活动期   返场期 预热期   活动期 返场期
# chanelID
# 渠道-00       90  4724   546     5  461   0   9875  1335031     0   5   486   0
# 渠道-16       32  2512   282     2  230   0   4476   597083     0   2   239   0
# 渠道-19       38  1904   226     1  185   0   3752   550486     0   1   201   0
# 渠道-28       63  3604   423     2  386   1   3276  1066802  2685   2   407   1
# 渠道-39      100  4993   570    12  489   0  38871  1347980     0  13   517   0
# 渠道-46       41  2512   252     4  244   0   8927   634642     0   4   256   0
# 渠道-52      146  7442   846     8  759   0  17262  2072188     0   8   806   0
# 渠道-53      123  6990   796     4  727   0   8783  1982162     0   4   760   0
# 渠道-56       59  2489   293     5  269   0  14250   808176     0   6   301   0
# 渠道-76      126  5476   611    10  583   1  35016  1616678  4108  10   622   1
# 渠道-78       42  1980   224     5  201   0  25171   522614     0   5   210   0
# 渠道-89      176  9982  1173    12  993   0  34383  2772357     0  13  1046   0
# 渠道-98       90  3737   445     7  389   0  14285  1042714     0   7   413   0
#
#          购买商品数
# tag        预热期   活动期 返场期
# chanelID
# 渠道-00        9  1339   0
# 渠道-16        7   601   0
# 渠道-19        4   546   0
# 渠道-28        4  1058   3
# 渠道-39       38  1400   0
# 渠道-46        9   650   0
# 渠道-52       23  2097   0
# 渠道-53       13  1959   0
# 渠道-56       14   770   0
# 渠道-76       33  1631   4
# 渠道-78       18   534   0
# 渠道-89       30  2813   0
# 渠道-98       15  1066   0

# %%
temp_df6.to_excel('qusetion2.xlsx')

# %%
(temp_df6['购买用户数'] / temp_df6['拉新用户数'])[['预热期','活动期']]
# Out:
# tag            预热期       活动期
# chanelID
# 渠道-00     0.055556  0.097587
# 渠道-16     0.062500  0.091561
# 渠道-19     0.026316  0.097164
# 渠道-28     0.031746  0.107103
# 渠道-39     0.120000  0.097937
# 渠道-46     0.097561  0.097134
# 渠道-52     0.054795  0.101989
# 渠道-53     0.032520  0.104006
# 渠道-56     0.084746  0.108076
# 渠道-76     0.079365  0.106465
# 渠道-78     0.119048  0.101515
# 渠道-89     0.068182  0.099479
# 渠道-98     0.077778  0.104094

# %%
temp_df4
# Out:
#             userID  购买商品数  订单数  消费金额  是否购买  age sex       date chanelID  tag
# 0      user-550507    0.0  0.0   0.0   0.0   39   女 2021-01-12    渠道-52  返场期
# 1      user-499937    0.0  0.0   0.0   0.0   30   男 2021-01-08    渠道-89  活动期
# 2      user-515582    0.0  0.0   0.0   0.0   39   女 2021-01-09    渠道-89  活动期
# 3      user-519645    0.0  0.0   0.0   0.0   34   男 2021-01-10    渠道-00  活动期
# 4      user-529356    0.0  0.0   0.0   0.0   24   女 2021-01-08    渠道-19  活动期
# ...            ...    ...  ...   ...   ...  ...  ..        ...      ...  ...
# 66153  user-531290    0.0  0.0   0.0   0.0   24   女 2021-01-08    渠道-52  活动期
# 66154  user-537409    0.0  0.0   0.0   0.0   33   女 2021-01-10    渠道-39  活动期
# 66155  user-511000    0.0  0.0   0.0   0.0   40   女 2021-01-09    渠道-98  活动期
# 66156  user-518649    0.0  0.0   0.0   0.0   36   女 2021-01-10    渠道-00  活动期
# 66157  user-545810    0.0  0.0   0.0   0.0   18   女 2021-01-10    渠道-39  活动期
#
# [66158 rows x 10 columns]

# %%
temp_df8 = pd.pivot_table(
    temp_df4,
    index='sex',
    values=['订单数', '购买商品数', '消费金额', '是否购买'],
    aggfunc={
        '订单数': 'sum',
        '购买商品数': 'sum',
        '消费金额': 'sum',
        '是否购买': 'count'
    }).applymap(int)
temp_df8.to_excel('question3.xlsx')

# %%
# 男性还是女性用户对营收贡献更大
temp_df7 = pd.pivot_table(
    temp_df4,
    index='sex',
    values=['订单数', '购买商品数', '消费金额'],
    aggfunc={
        '订单数': 'sum',
        '购买商品数': 'sum',
        '消费金额': 'sum'
    })
temp_df7
# Out:
#            消费金额     订单数    购买商品数
# sex
# 女    11106698.0  4234.0  11209.0
# 男     5467335.0  2112.0   5479.0

# %%
age_ser = pd.cut(temp_df4.age, bins=[15, 25, 35, 45, 55, 65], right=False)
temp_df4['年龄段'] = age_ser

# %%
temp_df4['年龄段'].value_counts().to_excel('年龄段统计.xlsx')

# %%
# 那个年龄段的用户对营收贡献更大
temp_df8 = pd.pivot_table(
    temp_df4,
    index=['年龄段', 'sex'],
    values=['订单数', '购买商品数', '消费金额'],
    aggfunc={
        '订单数': 'sum',
        '购买商品数': 'sum',
        '消费金额': 'sum'
    })
temp_df8.to_excel('qusetion4.xlsx')

# %%
temp_df9 = pd.pivot_table(
    temp_df4,
    index=['年龄段'],
    values=['订单数', '购买商品数', '消费金额'],
    aggfunc={
        '订单数': 'sum',
        '购买商品数': 'sum',
        '消费金额': 'sum'
    })
temp_df9.to_excel('qusetion5.xlsx')
